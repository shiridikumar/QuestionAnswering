# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer
import string
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import sent_tokenize
import re

# %%
stopwordSet = set(stopwords.words('english'))
punctuationSet = set(string.punctuation)
porterStemmer = PorterStemmer()

# %% [markdown]
# ### PreProcessing

# %%
def wordTokenize(line):
    wordsInLine = word_tokenize(line)
    return wordsInLine

def removeStopwords(line):
    wordsInLine = wordTokenize(line)
    lineWithoutStopwords = [word.lower() for word in wordsInLine if word.lower() not in stopwordSet and word.lower() not in punctuationSet]
    return lineWithoutStopwords

def stemming(line):
    wordsInLine = wordTokenize(line)
    ps = PorterStemmer()
    lineAfterStemming = [ps.stem(word) for word in wordsInLine]
    return lineAfterStemming

# %%
def parseParagraph(paragraph_fileName):
    para_dict = {}
    with open(paragraph_fileName) as f:
        parts = f.read().split("TEXT:")
        headline = parts[0].splitlines()[0]
        date = parts[0].splitlines()[1]
        storyId = parts[0].splitlines()[2]
        text = sent_tokenize(parts[1].lstrip("\n").replace("\n", " "))
        para_dict[(headline, date, storyId)] = text
    return para_dict

# %%
def removeStopwordsAndTagPos(paragraph_dict):
    paragraphWithoutStopwords = {}
    paragraphWithPos = {}
    for key in paragraph_dict:
        text = paragraph_dict[key]
        for line in text:
            lineWithoutStopwords = removeStopwords(line)
            paragraphWithoutStopwords[line] = lineWithoutStopwords
            paragraphWithPos[line] = nltk.pos_tag(lineWithoutStopwords)

    return paragraphWithoutStopwords, paragraphWithPos

# %%
def camelCase(word):
    return word != word.lower() and word != word.upper() and "_" not in word

def sentWithoutCamel(sent):
    sentWithoutCamel = []
    for word in sent:
        if camelCase(word):
            sentWithoutCamel.append(word)
    return sentWithoutCamel

# %%
name_list = []
location_list = []
month_list = []
time_list = []
organization_list = []
occupation_list = []
preposition_list = []
location_preposition_list = []
numberInWords_list = []
relative_timeList = ["today","tomorrow","yesterday","last week","last month","last year","next week","next month","next year"]

# %% [markdown]
# ### Semantic Classes

# %%
def semanticClasses(name_filename):
    with open(name_filename+"names.txt") as f:
        name_list.append(f.read().splitlines())

    with open(name_filename+"location.txt") as f:
        location_list.append(f.read().splitlines())

    with open(name_filename+"month.txt") as f:
        month_list.append(f.read().lower().splitlines())

    with open(name_filename+"time.txt") as f:
        time_list.append(f.read().lower().splitlines())

    with open(name_filename+"occupation.txt") as f:
        occupation_list.append(f.read().lower().splitlines())

    with open(name_filename+"location_preposition.txt") as f:
        location_preposition_list.append(f.read().lower().splitlines())

    with open(name_filename+"preposition.txt") as f:
        preposition_list.append(f.read().lower().splitlines())

    with open(name_filename+"numberInWords.txt") as f:
        numberInWords_list.append(f.read().lower().splitlines())

# %%
def wordMatch(ques, line, paraPOS_dict):
    wordsInQuestion = wordTokenize(ques)
    roots = set()
    for word in wordsInQuestion:
        roots.add(porterStemmer.stem(word))
    verbMatch = 0
    rootMatch = 0
    if line in paraPOS_dict:
        scoreOfLine = {}
        for (word, tag) in paraPOS_dict[line]:
            if 'V' in tag:
                ver_root = porterStemmer.stem(word)
                if ver_root in roots:
                    verbMatch += 6
            else:
                word_root = porterStemmer.stem(word)
                if word_root in roots:
                    rootMatch += 3
        scoreOfLine[line] = verbMatch + rootMatch
    return verbMatch + rootMatch

# %% [markdown]
# ### Who Rules

# %%
def containsNoun(ques):
    status = False
    pNList = sentWithoutCamel(ques)
    for p_n in pNList:
        if any(p_n in s for s in name_list):
            status = True
            return status 
        
    return status

# %%
def contains_word_name(ans_sent):
    flg = False
    for word in ans_sent:
        if word == "name":
            flg = True
            break
    return flg

def contains_proper_noun(ques):
    flg = False
    for word in ques:
        if (camelCase(word)):
            flg = True
            break
    return flg

# %%
def contains_name_occupation(sent):
    flg = False
    nounList = sentWithoutCamel(sent)
    for noun in nounList:
        if any(noun in s for s in name_list):
            flg = True
            return flg 
        
    for word in sent:
        if any(word in s for s in occupation_list):
            flg = True
            return flg
        
    return flg

# %%
def contains_month(question):
    wordInQuestion = wordTokenize(question)
    status = False
    for word in wordInQuestion:
        if word.lower() in month_list[0]:
            status = True
    return status

def contains_relativeTime(sent):
    wordsInSent = wordTokenize(sent)
    status = False
    for word in wordsInSent:
        if word.lower() in relative_timeList:
            status = True
    return status

def contains_head(wordsInQues, wordsInSent):
    status = False
    wordsInSentLower = [word.lower() for word in wordsInSent]
    for word in wordsInQues:
        if word.lower() in wordsInSentLower:
            status = True
    return status

def who(quesWithoutStop, sentWithoutStop, paraPOS_dict):
    score = 0
    flg = False
    if(not containsNoun(quesWithoutStop) and containsNoun(sentWithoutStop)):
        score += 6
    if ( not containsNoun(quesWithoutStop) and contains_word_name(sentWithoutStop)):
        score += 4
    status = contains_name_occupation(sentWithoutStop)
    if status:
        score += 4
    return score

# %% [markdown]
# ### When Rules

# %%
def contains_time_list(sent):
    wordsInSent = wordTokenize(sent)
    wordsInSent = [word for word in wordsInSent if word not in punctuationSet]
    for word in wordsInSent:
        if word.lower() in time_list[0]:
            return True
    return False

def contains_time_other(sent, custom_list):
    wordsInSent = wordTokenize(sent)
    wordsInSent = [word for word in wordsInSent if word not in punctuationSet]
    for word in wordsInSent:
        if word.lower() in custom_list:
            return True
    return False

def when_rule(ques, sent):
    score = 0
    if(contains_time_list(sent)):
        score += 4
    if(contains_time_other(ques,["last"]) and contains_time_other(sent,["first","last","since","ago"])):
        score += 20
    if(contains_time_other(ques,["start","begin"]) and contains_time_other(sent,["start","begin","since","year"])):
        score += 20
    return score

# %% [markdown]
# ### What rules

# %%
def what_rule(ques, sent):
    wordsInQues = wordTokenize(ques)
    wordsInSent = wordTokenize(sent)
    score = 0
    if(contains_month(ques) and contains_relativeTime(sent)):
        score += 3
    
    for ques_word in wordsInQues:
        if ques_word.lower() == "kind":
            for sent_word in wordsInSent:
                if ((sent_word == "call") or (sent_word == "from")):
                    score += 4

    for ques_word in wordsInQues:
        if ques_word == "name":
            for sent_word in wordsInSent:
                if ((sent_word == "name") | (sent_word == "call") | (sent_word == "known")):
                    score += 20
    wordsAfterOfInQues = []
    for ind,ques in enumerate(wordsInQues):
        if ques.lower() == "of":
            for rem_ind in range(ind+1,len(wordsInQues)):
                if wordsInQues[rem_ind].lower() in name_list[0]:
                    wordsAfterOfInQues.append(wordsInQues[rem_ind].lower())

    for ind,ques in enumerate(wordsAfterOfInQues):
        if ques == "name":
            if wordsInQues[ind+1].lower() in preposition_list[0]:
                sentWithoutStop = removeStopwords(sent)
                if contains_proper_noun(sentWithoutStop):
                    if contains_head(wordsAfterOfInQues,wordsInSent):
                        score += 20

    return score

# %% [markdown]
# ### Why rules

# %%
def why_rule(sent, BESTlines, text_list, index):
    wordsInASent = wordTokenize(sent)
    score = 0

    if sent in BESTlines:
        score += 3

    if sent not in BESTlines:
        if (index + 1) < len(text_list):
            if text_list[index+1] in BESTlines:
                score += 3
        if text_list[index - 1] in BESTlines:
            score += 4
    for word in wordsInASent:
        if word.lower() == "want":
            score+= 4
        if ((word.lower() == "so") | (word.lower() == "because")):
           score += 4

    return score

def get_bestLines(ques, text_list, paraPOS_dict):
    scoresOfLine = {}
    BESTLines = []
    for line in text_list:
        scoresOfLine[line] = wordMatch(ques, line, paraPOS_dict)
    scoresOfLine = {line:score for line,score in scoresOfLine.items() if score is not None}
    maxIndex = max(scoresOfLine, key=scoresOfLine.get)
    
    mxScore = scoresOfLine[maxIndex]
    twoThirdScore = mxScore * 2 / 3
    for line in scoresOfLine:
        if scoresOfLine[line] >= twoThirdScore:
            BESTLines.append(line[0])
    return BESTLines

# %% [markdown]
# ### Where Rules

# %%
def contains_location_preposition(sent):
    wordsInSent = wordTokenize(sent)
    wordsInSent = [word for word in wordsInSent if word not in punctuationSet]
    for word in wordsInSent:
        if word.lower() in location_preposition_list[0]:
            return True
    return False


def contains_location_list(sent):
    wordsInSent = wordTokenize(sent)
    wordsInSent = [word for word in wordsInSent if word not in punctuationSet]
    for word in wordsInSent:
        if word.lower() in location_list[0]:
            return True
    return False


def where_rule(ques, sent):
    score = 0
    if(contains_location_list(sent)):
        score += 6
    if(contains_location_preposition(sent)):
        score += 4
    return score


def contains_word(ques, check):
    wordsInQues = wordTokenize(ques)
    wordsInQues = [word for word in wordsInQues if word not in punctuationSet]
    for word in wordsInQues:
        if word.lower() == check:
            return True
    return False


def dateLine(question):
    score = 0
    if (contains_word(question, "happen")):
        score = score + 4
    if (contains_word(question, "take") and contains_word(question, "place")):
        score = score + 4
    if (contains_word(question, "this")):
        score = score + 20
    if (contains_word(question, "story")):
        score = score + 20
    return score

# %% [markdown]
# ### How Rules

# %%
def how_rule(sent, question, storyPOS_dict):

    scoreOfHowRule = 0
    wordsInASentence = wordTokenize(sent.lower())
    wordsInAQuestion = wordTokenize(question.lower())

    scoreOfWordMatch = wordMatch(question, sent, storyPOS_dict)
    scoreOfHowRule = scoreOfHowRule + scoreOfWordMatch + 10
    if "cost" in wordsInAQuestion or "much" in wordsInAQuestion or "many" in wordsInAQuestion or "long" in wordsInAQuestion:

        if (("dollar" in wordsInASentence) or ("cost" in wordsInASentence) or (re.match(r'\d+', sent) != None) or ("weigh" in wordsInASentence)):
            scoreOfHowRule = scoreOfHowRule + 12
        for word in wordsInASentence:
            if word in numberInWords_list:
                scoreOfHowRule = scoreOfHowRule + 6

    if "age" in wordsInAQuestion or "old" in wordsInAQuestion:
        if (re.search(r'\d+', sent) != None):
            scoreOfHowRule = scoreOfHowRule + 20
        for word in wordsInASentence:
            if word in numberInWords_list:
                scoreOfHowRule = scoreOfHowRule + 20

    return scoreOfHowRule

# %%
def matchForAccuracy(real_answer, predicted_answer):
    real_answer = real_answer.lower()
    predicted_answer = predicted_answer.lower()
    real_answer = real_answer.split()
    predicted_answer = predicted_answer.split()
    score = 0
    for word in predicted_answer:
        if word in real_answer:
            score += 1
    if(len(predicted_answer) == 0):
        return 0    
    return score / len(predicted_answer)

# %%
def data_forward(questions_data, story_dict):
    storyWithoutStopWords_dict, storyPOS_dict =removeStopwordsAndTagPos(
        story_dict)
    quest_words = set(['what', 'when', 'why', 'who',
                      'where', 'whose', 'which', 'how'])
    total_accuracy = 0

    
    for question in questions_data:
        for story_key in story_dict:
            text_list = story_dict[story_key]
            questionWithoutStopWords = removeStopwords(question[1])
            BESTlines = get_bestLines(question[1], text_list, storyPOS_dict)
            acc = 0
            ans = ""
            for q in question[1].split():
                if q.lower() in quest_words:
                    if q.lower() == 'who' or q.lower() == 'whose':
                        max_score_who = 0
                        answer = ""
                        for sent in text_list:
                            scoreOfASentence = wordMatch(
                                question[1], sent, storyPOS_dict)
                            sentWithoutStopWords = removeStopwords(sent)
                            who_score = who(
                                questionWithoutStopWords, sentWithoutStopWords, storyPOS_dict)
                            who_score += scoreOfASentence

                            if (max_score_who < who_score):
                                max_score_who = who_score
                                answer = sent
                        ans = ""

                        str1_list = word_tokenize(answer)
                        str2_list = word_tokenize(question[1].lower())
                        for word in str1_list:
                            if word.lower() not in str2_list and word.lower() not in punctuationSet and not word.islower():
                               ans = ans+" "+word
                        if ans == "":
                            for word in str1_list:
                                if word.lower() not in str2_list and word.lower() not in punctuationSet:
                                   ans = ans+" "+word

                        if 'being' in question[0] and 'being' in ans:
                            ans = ans.split('being')[1]

                        print ("QuestionID:", question[0])
                        print ("Answer:", ans)

                        break
                    if (q.lower() == 'when'):
                        max_score_when = 0
                        date = ""
                        count = 0
                        for sent in text_list:
                            scoreOfASentence = wordMatch(
                                question[1], sent, storyPOS_dict)
                            when_score = when_rule(
                                question[1], sent)
                            when_score += scoreOfASentence
                            dateline_score = dateLine(question[1])
                            first_sent = text_list[0]
                            if (max_score_when < when_score):
                                max_score_when = when_score
                                answer = sent

                            if (when_score == max_score_when):
                                count = count+1

                            if count == len(text_list):
                                answer = first_sent
                            if max_score_when == 0:
                                max_score_when = dateline_score
                                date = story_key[1].split(":")[1].lstrip()
                                answer = sent
                        date = ""
                        if date == "":
                            ans = ""
                            str1_list = word_tokenize(answer)
                            str2_list = word_tokenize(question[1].lower())
                            for word in str1_list:
                                if word.lower() not in str2_list and word.lower() not in punctuationSet:
                                   ans = ans+" "+word

                            if 'being' in question[0] and 'being' in ans:
                                ans = ans.split('being')[1]

                            print( "QuestionID:", question[0])
                            if (re.search(r'\d+', ans) != None):
                                print("Answer:", re.sub('[^\d.]', ' ', ans))
                            else:
                                print("Answer:", ans)
                        else:
                            ans = ""
                            str1_list = word_tokenize(answer)
                            str2_list = word_tokenize(question[1].lower())
                            for word in str1_list:
                                if word.lower() not in str2_list and word.lower() not in punctuationSet:
                                   ans = ans+" "+word
                            print("QuestionID:", question[0])
                            print("Answer:", date)
                        break
                    if(q.lower() == 'where'):
                        max_score_where = 0
                        date = ""
                        count = 1
                        for sent in text_list:
                            scoreOfASentence = wordMatch(
                                question[1], sent, storyPOS_dict)
                            where_score = where_rule(
                                question[1], sent)
                            where_score += scoreOfASentence
                            dateline_score = dateLine(question[1])
                            first_sent = text_list[0]

                            if (max_score_where < where_score):
                                max_score_where = where_score
                                answer = sent

                            if (where_score == max_score_where):
                                count = count+1

                            if count == len(text_list):
                                answer = first_sent

                            if max_score_where == 0:
                                max_score_where = dateline_score
                                date = story_key[1].split(":")[1].lstrip()
                                answer = sent
                            date = ""

                        if date == "":
                            ans = ""
                            str1_list = word_tokenize(answer)
                            str2_list = word_tokenize(question[1].lower())
                            for word in str1_list:
                                if word.lower() not in str2_list and word.lower() not in punctuationSet and not word.islower():
                                   ans = ans+" "+word

                            if 'being' in question[0] and 'being' in ans:
                                ans = ans.split('being')[1]

                            if ('where' in question[0]) and 'from ' in ans:
                                ans = ans[ans.index('from '):]

                            print("QuestionID:", question[0])
                            print ("Answer:", ans)
                        else:
                            ans = ""
                            str1_list = word_tokenize(answer)
                            str2_list = word_tokenize(question[1].lower())
                            for word in str1_list:
                                if word.lower() not in str2_list and word.lower() not in punctuationSet:
                                   ans = ans+" "+word
                            print ("QuestionID:", question[0])
                            print ("Answer:", date)
                        break

                    if(q.lower() == 'what' or q.lower() == 'which'):
                        max_score_what = 0
                        answer = ""
                        for sent in text_list:
                            scoreOfASentence = wordMatch(
                                question[1], sent, storyPOS_dict)
                            scoreOfWhatRule = what_rule(
                                question[1], sent)
                            scoreOfWhatRule += scoreOfASentence
                            if (scoreOfWhatRule == max_score_what):
                                answer = answer + " | "+sent

                            if (max_score_what < scoreOfWhatRule):
                                max_score_what = scoreOfWhatRule
                                answer = sent

                        ans = ""
                        if "|" in answer:
                            str1_list = word_tokenize(answer.split("|")[1])
                        else:
                            str1_list = word_tokenize(answer)
                        str2_list = word_tokenize(question[1].lower())
                        for word in str1_list:
                            if word.lower() not in str2_list and word.lower() not in punctuationSet:
                               ans = ans+" "+word

                        if 'being' in question[0] and 'being' in ans:
                            ans = ans.split('being')[1]

                        print("QuestionID:", question[0])
                        print("Answer:", ans)
                        break

                    if(q.lower() == 'why'):
                        index = -1
                        max_score_why = 0
                        answer = ""
                        for sent in text_list:
                            index = index + 1
                            scoreOfWhyRule = why_rule(
                                sent, BESTlines, text_list, index)

                            if (scoreOfWhyRule == max_score_why):
                                answer = answer + " | "+sent

                            if (max_score_why < scoreOfWhyRule):
                                max_score_why = scoreOfWhyRule
                                answer = sent

                        ans = ""
                        str1_list = word_tokenize(answer)
                        str2_list = word_tokenize(question[1].lower())

                        if("|" in answer):
                            ans = answer.split("|")[-1]
                        else:
                            ans = answer

                        if 'being' in question[0] and 'being' in ans:
                            ans = ans.split('being')[1]
                        if 'because' in ans:
                            ans = ans[ans.index('because '):]

                        elif 'for ' in ans:
                            ans = ans[ans.index('for '):]

                        elif 'to ' in ans:
                            ans = ans[ans.index('to '):]

                        print("QuestionID:", question[0])
                        print("Answer:", ans)
                        break

                    if(q.lower() == 'how'):
                        max_score_how = 0
                        for sent in text_list:
                            scoreOfHowRule = how_rule(
                                sent, question[1], storyPOS_dict)
                            if (scoreOfHowRule == max_score_how):
                                answer = answer + " | "+sent

                            if (scoreOfHowRule > max_score_how):
                                max_score_how = scoreOfHowRule
                                answer = sent

                        ans = ""

                        if ("|" in answer):
                            str1_list = word_tokenize(answer.split("|")[1])
                        else:
                            str1_list = word_tokenize(answer)
                        str2_list = word_tokenize(question[1].lower())

                        print("QuestionID:", question[0])
                        tagAnswer = nltk.pos_tag(str1_list)
                        if "how many" in question[1].lower() or "how much" in question[1].lower():
                            for i in range(0, len(tagAnswer)):
                                if 'CD' in tagAnswer[i][1]:
                                    ans = ans + " " + tagAnswer[i][0]
                                else:
                                    ans = answer
                        else:
                            for word in str1_list:
                                if word.lower() not in str2_list and word.lower() not in punctuationSet:
                                   ans = ans+" "+word

                        if 'being' in question[0] and 'being' in ans:
                            ans = ans.split('being')[1]

                        if 'how' in question[0] and 'by ' in ans:
                            ans = ans[ans.index('by '):]

                        if ('how' in question[0]) and 'from ' in ans:
                            ans = ans[ans.index('from '):]
                        print("Answer:", ans)
                        break
            acc += matchForAccuracy(question[2], ans)            

        if not any(word in question[1].lower().split() for word in quest_words):
                max_score_else = 0
                for sent in text_list:
                    current_score = wordMatch(question[1], sent, storyPOS_dict)

                    if (current_score == max_score_else):
                          answer = answer + " | "+sent

                    if current_score > max_score_else:
                        max_score_else = current_score
                        answer = sent

                ans = ""
                if ("|" in answer):
                    str1_list = word_tokenize(answer.split("|")[1])
                else:
                    str1_list = word_tokenize(answer)
                str2_list = word_tokenize(question[1].lower())
                for word in str1_list:
                    if word.lower() not in str2_list and word.lower() not in punctuationSet:
                        ans = ans+" "+word

                if 'being' in question[0] and 'being' in ans:
                    ans = ans.split('being')[1]

                print("QuestionID:", question[0])
                print("Answer:", ans)
                acc += matchForAccuracy(question[2], ans)
        print("\n")

        total_accuracy += acc

    print("Total Accuracy: ", total_accuracy / len(questions_data) * 100)
    return total_accuracy / len(questions_data) * 100

# %%
semanticClasses("./")

# %%
input_path  = "./testset1/"
input_file = open(input_path+"testset1.txt")
input_data = input_file.read().splitlines()
print(input_data)
# Out:
# ['1999-W07-5', '1999-W08-1', '1999-W08-5', '1999-W09-5', '1999-W20-4', '1999-W26-1', '1999-W27-3', '1999-W28-1', '1999-W29-4', '1999-W31-1', '1999-W31-3', '1999-W31-5', '1999-W32-4', '1999-W32-5', '1999-W33-3', '1999-W33-5', '1999-W34-4', '1999-W35-5', '1999-W37-2', '1999-W37-4', '1999-W38-1', '1999-W39-1', '1999-W39-3', '1999-W39-5', '1999-W41-3', '1999-W41-5', '1999-W43-5', '1999-W45-5', '1999-W47-5', '1999-W49-5', '1999-W51-1', '2000-W02-3', '2000-W02-5', '2000-W03-1', '2000-W03-2', '2000-W03-3', '2000-W05-4', '2000-W06-5', '2000-W07-5']

# %%
total_accuracy = 0
for i in range(0,len(input_data)):
    story = input_data[i] + ".story"
    questions = input_data[i] + ".questions"
    answers = input_data[i] + ".answers"
    answer_file = open(input_path+answers)
    answer_data = answer_file.read().splitlines()
    answers_total = list(filter(None, answer_data))

    questions_data = []
    for j in range(0, len(answers_total), 4):
        question_temp = []
        quesid = answers_total[j].split(":")[1].lstrip(" ")
        question_temp.append(quesid)
        ques = answers_total[j+1].split(":")[1].lstrip(" ")
        question_temp.append(ques)
        answer = answers_total[j+2].split(":")[1].lstrip(" ")
        question_temp.append(answer)
        questions_data.append(question_temp)
    para_dict = parseParagraph(input_path+story)
    total_accuracy += data_forward(questions_data, para_dict)

print("Total Accuracy: ", total_accuracy / (len(input_data)-1))
# Out:
# QuestionID: 1999-W07-5-1
# Answer:  Shivering Alberta
#
#
# QuestionID: 1999-W07-5-2
# Answer:  But Kolla
#
#
# QuestionID: 1999-W07-5-4
# Answer:  Father Michael Kolla was at resort after a sleepless night he got word safe and sound
#
#
# QuestionID: 1999-W07-5-5
# Answer:  Shivering Alberta
#
#
# QuestionID: 1999-W07-5-6
# Answer:  Using their hands two dug into hollow around base of a tree covered floor with pine boughs and settled in for a long cold night
#
#
# QuestionID: 1999-W07-5-7
# Answer:  "We were so happy."
#
#
# QuestionID: 1999-W07-5-8
# Answer:  His Carol Sandpoint ``
#
#
# QuestionID: 1999-W07-5-12
# Answer:  `` They helped my live ''
#
#
# Total Accuracy:  8.03125
# QuestionID: 1999-W08-1-1
# Answer:  The senators were split 50-50 on the charge of obstruction of justice and only 45 voted Clinton guilty on the charge of
#
#
# QuestionID: 1999-W08-1-2
# Answer: The senators were split 50-50 on the charge of obstruction of justice, and only 45 voted Clinton "guilty" on the charge of perjury.
#
#
# QuestionID: 1999-W08-1-3
# Answer:  President charge lying in court hiding evidence or getting others to lie in court
#
#
# QuestionID: 1999-W08-1-4
# Answer:  Clinton White House
#
#
# QuestionID: 1999-W08-1-5
# Answer:  Republican
#
#
# QuestionID: 1999-W08-1-7
# Answer:  In fact rating climbed which means Americans think he is still fit be their president
#
#
# Total Accuracy:  29.61352657004831
# QuestionID: 1999-W08-5-2
# Answer:  These satellites forecast crop yields keep track of ice conditions in Arctic ocean and mining companies look for mineral resources
#
#
# QuestionID: 1999-W08-5-4
# Answer: to launch the satellite.
#
#
# QuestionID: 1999-W08-5-5
# Answer:  NASA
#
#
# QuestionID: 1999-W08-5-6
# Answer:  `` Anything U.S. '' Hugues Gilbert
#
#
# Total Accuracy:  30.833333333333336
# QuestionID: 1999-W09-5-1
# Answer:  BCC
#
#
# QuestionID: 1999-W09-5-2
# Answer:                            16
#
#
# QuestionID: 1999-W09-5-3
# Answer: When Moshe Akavak became a jail guard 16 years ago, he was appalled so many Inuit had lost their traditional skills.
#
#
# QuestionID: 1999-W09-5-5
# Answer: "Whenever you have inmates that come out of jail feeling good about themselves and wanting to succeed I think that cost is well borne out in terms of perhaps reduced recidivism [a return to committing crimes].
#
#
# QuestionID: 1999-W09-5-6
# Answer:  `` If ''
#
#
# QuestionID: 1999-W09-5-7
# Answer:  party is hunting caribou far from city on frozen tundra
#
#
# QuestionID: 1999-W09-5-8
# Answer:  Inmates Iqaluit Baffin Island North West Territories Nunavut
#
#
# Total Accuracy:  19.375820503640053
# QuestionID: 1999-W20-4-2
# Answer:  Ottawa
#
#
# QuestionID: 1999-W20-4-4
# Answer:  's launching a Charter challenge against Ottawa 's anti-panhandling laws after he ticketed on the street
#
#
# QuestionID: 1999-W20-4-6
# Answer:  O'Neill --
#
#
# QuestionID: 1999-W20-4-7
# Answer:  Here 's Charter says Everyone has following fundamental freedoms conscience and religion thought belief opinion and including press and other media communication peaceful assembly and association
#
#
# Total Accuracy:  28.846153846153843
# QuestionID: 1999-W26-1-1
# Answer:  Over NATO Yugoslavians Albanian Yugoslavian
#
#
# QuestionID: 1999-W26-1-2
# Answer:  says that will hand over their large weapons NATO forces and stop wearing military uniforms
#
#
# QuestionID: 1999-W26-1-3
# Answer:  Hundreds Albanians Yugoslavia
#
#
# QuestionID: 1999-W26-1-6
# Answer:  At top agenda was coming and make sure that lasting peace can be maintained
#
#
# QuestionID: 1999-W26-1-7
# Answer: It could cost more than a hundred billion dollars to rebuild what NATO destroyed in Yugoslavia.
#
#
# QuestionID: 1999-W26-1-9
# Answer: to see a democratic society there -- that's the only way that you're going to bring ultimate peace, stability and reconstruction to the area," says Canada's Foreign Affairs Minister Lloyd Axworthy.
#
#
# Total Accuracy:  44.278673835125446
# QuestionID: 1999-W27-3-1
# Answer: because of Sarah McLachlan's fame, but also because of the legal issues it raises.
#
#
# QuestionID: 1999-W27-3-2
# Answer:  The McLachlan Justice Bruce Cohen Canadian
#
#
# QuestionID: 1999-W27-3-4
# Answer:  Mr. is suing Ms. for song writing credit and a share of money from her recorded more than 10 years ago
#
#
# QuestionID: 1999-W27-3-5
# Answer:  Mr. for pre-production coordination and production assistance
#
#
# QuestionID: 1999-W27-3-6
# Answer:  `` What '' Ms. McLachlan ``
#
#
# QuestionID: 1999-W27-3-8
# Answer:  act came into effect in 1924 and the in the United Kingdom
#
#
# QuestionID: 1999-W27-3-9
# Answer: because of Sarah McLachlan's fame, but also because of the legal issues it raises.
#
#
# QuestionID: 1999-W27-3-10
# Answer:          1924
#
#
# Total Accuracy:  25.0
# QuestionID: 1999-W28-1-1
# Answer:  Funeral
#
#
# QuestionID: 1999-W28-1-2
# Answer:  When it discovered the cancer had spread to 's lungs the province dropped the case
#
#
# QuestionID: 1999-W28-1-3
# Answer:  Shortly after 's took the boy Mexico the alternative
#
#
# QuestionID: 1999-W28-1-4
# Answer:  The funeral was held in Gruenthal, north of Saskatoon.
#
#
# QuestionID: 1999-W28-1-5
# Answer:  He says in government interference meant alternative may have been too
#
#
# QuestionID: 1999-W28-1-6
# Answer:  it was discovered cancer had spread to 's lungs province dropped
#
#
# QuestionID: 1999-W28-1-7
# Answer:  When
#
#
# QuestionID: 1999-W28-1-8
# Answer:  The funeral was held in Gruenthal, north of Saskatoon.
#
#
# Total Accuracy:  17.424242424242426
# QuestionID: 1999-W29-4-1
# Answer: to talk.
#
#
# QuestionID: 1999-W29-4-2
# Answer:  a very rare form of brain that can occur at any time in childhood
#
#
# QuestionID: 1999-W29-4-3
# Answer:  is a very rare form of brain that at any time in childhood
#
#
# QuestionID: 1999-W29-4-4
# Answer:  It is not known causes but it is known that become inflamed or puffy when infected
#
#
# QuestionID: 1999-W29-4-5
# Answer:  As a result affected cells malfunction and fire they are
#
#
# QuestionID: 1999-W29-4-6
# Answer:  is a very rare form that can occur at any time in childhood
#
#
# QuestionID: 1999-W29-4-7
# Answer:  left side brain controls speech and some body movements so could leave without ability talk
#
#
# QuestionID: 1999-W29-4-8
# Answer:  The surgery Amber called and younger patients
#
#
# Total Accuracy:  35.98328754578755
# QuestionID: 1999-W31-1-1
# Answer: because they steal bait and will also hit lures.
#
#
# QuestionID: 1999-W31-1-2
# Answer:  Environment Canada
#
#
# QuestionID: 1999-W31-1-3
# Answer:  is reducing precious sport fish stocks in lake
#
#
# QuestionID: 1999-W31-1-4
# Answer:  also has advantage of being able right through night
#
#
# QuestionID: 1999-W31-1-5
# Answer:  Environment Canada Ontario
#
#
# QuestionID: 1999-W31-1-6
# Answer:  came from Black Sea in water held in bottom of a boat
#
#
# QuestionID: 1999-W31-1-7
# Answer:  officials hope these measures will taking over waterways of central Canada
#
#
# Total Accuracy:  33.730158730158735
# QuestionID: 1999-W31-3-1
# Answer:  John Hamm Nova Scotia
#
#
# QuestionID: 1999-W31-3-2
# Answer:  The PC Liberal Party Premier Robert Chisholm New Democratic Party
#
#
# QuestionID: 1999-W31-3-3
# Answer: The Conservatives were able to win a majority government, meaning they will have more members in the legislature than both parties combined. | That means that no one party had more than half the seats in the legislature.
#
#
# QuestionID: 1999-W31-3-4
# Answer:  When the is defeated on major bill like one that is about money means the legislature has lost confidence in them
#
#
# QuestionID: 1999-W31-3-5
# Answer:  placed third
#
#
# QuestionID: 1999-W31-3-6
# Answer:  within three years
#
#
# QuestionID: 1999-W31-3-7
# Answer:  He says he will stay on as leader of the Nova Scotia Liberal Party despite losing his job as premier.
#
#
# QuestionID: 1999-W31-3-8
# Answer:  like one that about money means legislature has lost confidence in them
#
#
# QuestionID: 1999-W31-3-9
# Answer:  This means the either quit or call new election
#
#
# Total Accuracy:  43.91534391534392
# QuestionID: 1999-W31-5-1
# Answer:  may finally fulfill his to go to the moon
#
#
# QuestionID: 1999-W31-5-2
# Answer:  If all goes as planned on Saturday a lipstick-sized will carry his to moon south pole
#
#
# QuestionID: 1999-W31-5-3
# Answer:  NASA Earth
#
#
# QuestionID: 1999-W31-5-4
# Answer:  hopeful that impact of 's crash into moon a plume of water which be visible from Earth with a telescope
#
#
# QuestionID: 1999-W31-5-5
# Answer:  He craters and the collisions that cause them
#
#
# QuestionID: 1999-W31-5-6
# Answer: He is credited with discovering about 20 comets and 800 asteroids.
#
#
# QuestionID: 1999-W31-5-7
# Answer:                           1994
#
#
# QuestionID: 1999-W31-5-8
# Answer:  The comet slammed Jupiter in 1994
#
#
# QuestionID: 1999-W31-5-9
# Answer:  will be the first human to be laid to rest on another celestial body
#
#
# QuestionID: 1999-W31-5-10
# Answer: because of a medical problem.
#
#
# QuestionID: 1999-W31-5-11
# Answer:  said shortly before death the `` not going to the moon and banging on it with my own hammer ''
#
#
# Total Accuracy:  37.97504263413354
# QuestionID: 1999-W32-4-1
# Answer:  At Sweden Iranian Italian 3-1
#
#
# QuestionID: 1999-W32-4-2
# Answer: The teams play with five robots on each team.
#
#
# QuestionID: 1999-W32-4-3
# Answer:  At third annual Robot World Cup Soccer tournament in Sweden Iranian beat Italian 3-1
#
#
# QuestionID: 1999-W32-4-4
# Answer:  At third annual Robot World Cup Soccer tournament in Sweden Iranian beat Italian 3-1
#
#
# QuestionID: 1999-W32-4-5
# Answer:             2050
#
#
# QuestionID: 1999-W32-4-6
# Answer:  He Garry Kasparov
#
#
# QuestionID: 1999-W32-4-8
# Answer: Teams of human-size robots with two legs that walk and kick a ball are expected to be competing in the 2002 tournament.
#
#
# QuestionID: 1999-W32-4-9
# Answer:  Teams
#
#
# QuestionID: 1999-W32-4-11
# Answer:  Australia
#
#
# Total Accuracy:  37.29517396184063
# QuestionID: 1999-W32-5-1
# Answer:  Banff Alberta
#
#
# QuestionID: 1999-W32-5-2
# Answer:  They are usually by weakened land on hills and mountains
#
#
# QuestionID: 1999-W32-5-3
# Answer:  one metre and at its height covered all four lanes divided highway
#
#
# QuestionID: 1999-W32-5-4
# Answer: The mud was one metre deep in some areas of the road, and at its height covered all four lanes of the divided highway.
#
#
# QuestionID: 1999-W32-5-5
# Answer:  clean up crews were
#
#
# QuestionID: 1999-W32-5-6
# Answer:  say it take several days before all the debris is cleared and returns
#
#
# QuestionID: 1999-W32-5-7
# Answer:
#
#
# QuestionID: 1999-W32-5-8
# Answer:  They are caused by weakened land on hills and mountains
#
#
# QuestionID: 1999-W32-5-10
# Answer:  move and powerfully picking up rocks trees houses and cars
#
#
# Total Accuracy:  31.06125356125356
# QuestionID: 1999-W33-3-1
# Answer:  brightened millions people in Europe on Wednesday
#
#
# QuestionID: 1999-W33-3-2
# Answer:  In twenty five years an astronomer who observed every total would watch only about an hour of total eclipses
#
#
# QuestionID: 1999-W33-3-3
# Answer:  Atlantic Europe Turkey Iran India
#
#
# QuestionID: 1999-W33-3-4
# Answer:  In twenty five years an astronomer who observed every solar would watch only about an hour of eclipses
#
#
# QuestionID: 1999-W33-3-5
# Answer: The maximum number of eclipses there can be in one year is seven. | The minimum number of eclipses there can be in one year is two.
#
#
# QuestionID: 1999-W33-3-6
# Answer:  A partial eclipse {where the moon covers part, but not all of the sun} could be seen in Eastern Canada.
#
#
# QuestionID: 1999-W33-3-7
# Answer:  In twenty five years an astronomer who observed every solar eclipse would watch only about an hour of
#
#
# QuestionID: 1999-W33-3-8
# Answer: In twenty five years an astronomer who observed every total solar eclipse, would watch only about an hour of total eclipses.
#
#
# QuestionID: 1999-W33-3-9
# Answer:  Eastern Canada
#
#
# QuestionID: 1999-W33-3-10
# Answer:  The minimum number of eclipses there can be in one year two
#
#
# Total Accuracy:  24.19047619047619
# QuestionID: 1999-W33-5-2
# Answer:  Now
#
#
# QuestionID: 1999-W33-5-3
# Answer: because of it's an historical site.
#
#
# QuestionID: 1999-W33-5-4
# Answer:     1920
#
#
# QuestionID: 1999-W33-5-5
# Answer:  Bluenose was a famous schooner ship that raced for
#
#
# QuestionID: 1999-W33-5-6
# Answer: The Bluenose was a famous schooner ship that raced for the International Fisherman's Trophy.
#
#
# QuestionID: 1999-W33-5-7
# Answer:  A Canadian 1937
#
#
# QuestionID: 1999-W33-5-8
# Answer:  Canadian
#
#
# QuestionID: 1999-W33-5-9
# Answer:  a replica of original
#
#
# QuestionID: 1999-W33-5-10
# Answer: Now the Mayor wants the federal and provincial governments to pay half the cost of cleaning up Lunenburg Harbour.
#
#
# Total Accuracy:  31.448992852501622
# QuestionID: 1999-W34-4-1
# Answer:  3
#
#
# QuestionID: 1999-W34-4-2
# Answer:  centre earthquake hit Izmit region just south Istanbul country 's
#
#
# QuestionID: 1999-W34-4-3
# Answer:  centre of Izmit region just south of Istanbul country 's capital
#
#
# QuestionID: 1999-W34-4-4
# Answer:  Rescue
#
#
# QuestionID: 1999-W34-4-5
# Answer: The earthquake has reportedly killed more than 6,000 people, and left at least 21,000 injured.
#
#
# QuestionID: 1999-W34-4-6
# Answer: Because of the number of injuries, Turkish hospitals are overcrowded, and can't take anymore patients.
#
#
# QuestionID: 1999-W34-4-7
# Answer:  had a 7.8
#
#
# QuestionID: 1999-W34-4-8
# Answer:  measures the amount of energy released by an
#
#
# QuestionID: 1999-W34-4-9
# Answer:  vibrations that follow an earthquake
#
#
# QuestionID: 1999-W34-4-11
# Answer:  sent to Turkey on Wednesday night
#
#
# Total Accuracy:  38.416666666666664
# QuestionID: 1999-W35-5-2
# Answer:  group representing doctors who specialize in treating children may have for when they take their children for How much television do your kids watch
#
#
# QuestionID: 1999-W35-5-3
# Answer: because excessive and inappropriate exposure can harm a child's physical, mental and social skills.
#
#
# QuestionID: 1999-W35-5-4
# Answer: How much time does the average Canadian kid spend watching television each week? | The society wants parents to limit preschoolers to one hour of TV a day, while school children should watch no more than two hours daily.
#
#
# QuestionID: 1999-W35-5-5
# Answer:  Canadian
#
#
# QuestionID: 1999-W35-5-6
# Answer:  But violent
#
#
# QuestionID: 1999-W35-5-7
# Answer:  also believe televisions during meal times
#
#
# QuestionID: 1999-W35-5-9
# Answer: How much time does the average Canadian kid spend watching television each week?
#
#
# Total Accuracy:  32.95395081109366
# QuestionID: 1999-W37-2-3
# Answer:  means `` our land ''
#
#
# QuestionID: 1999-W37-2-4
# Answer:              1
#
#
# QuestionID: 1999-W37-2-5
# Answer:  Prime Minister Chretien
#
#
# QuestionID: 1999-W37-2-6
# Answer:  `` Here is a vast country land of aboriginal people land of at once English and speaking that is art of living together a spirit of peace and tolerance ''
#
#
# QuestionID: 1999-W37-2-7
# Answer: He arrived in the Nunavut capital of Iqaluit on Sunday accompanied by Canadian Prime Minister Jean Chretien.
#
#
# QuestionID: 1999-W37-2-9
# Answer:  Chirac visited a community hall run by the Francophone Association where he opened a virtual museum of Inuit art on the Internet a project financed by the French government
#
#
# QuestionID: 1999-W37-2-10
# Answer:  visited a community hall run by the Nunavut Francophone Association where opened a virtual museum of Inuit art on the Internet a project financed by the French government
#
#
# Total Accuracy:  32.08421299554304
# QuestionID: 1999-W37-4-1
# Answer:      60                                   1939                             1942
#
#
# QuestionID: 1999-W37-4-2
# Answer:  The Hong Kong 1939 Canada 1942
#
#
# QuestionID: 1999-W37-4-3
# Answer:  She the first immigrant to be named
#
#
# QuestionID: 1999-W37-4-4
# Answer:  Ms. says Prime Minister Jean Chretien approached her `` early in summer '' about replacing Governor-General Romeo LeBlanc who had asked to step down
#
#
# QuestionID: 1999-W37-4-5
# Answer:  She says she plans an active yet sensible
#
#
# QuestionID: 1999-W37-4-6
# Answer:  For example says she and her husband author John Ralston Saul more often
#
#
# QuestionID: 1999-W37-4-7
# Answer:  Ms. Prime Minister Jean Chretien `` '' Governor-General Romeo LeBlanc
#
#
# QuestionID: 1999-W37-4-9
# Answer:  who lives in Toronto is best known for with where she was a high-profile interviewer and host for three decades
#
#
# QuestionID: 1999-W37-4-10
# Answer: The Governor General, the legal head of the Canadian state, makes more than 300 public appearances a year.
#
#
# Total Accuracy:  20.32051282051282
# QuestionID: 1999-W38-1-1
# Answer: Prime Minister Jean Chretien says Canada will send as many as 600 soldiers to East Timor.
#
#
# QuestionID: 1999-W38-1-2
# Answer:  Indonesia Australia
#
#
# QuestionID: 1999-W38-1-3
# Answer:  Two weeks ago island voted
#
#
# QuestionID: 1999-W38-1-4
# Answer:  Indonesian
#
#
# QuestionID: 1999-W38-1-5
# Answer:  capitol Dili has been turned into a burning looted ghost town
#
#
# QuestionID: 1999-W38-1-7
# Answer:  United Nations
#
#
# QuestionID: 1999-W38-1-8
# Answer:                 30
#
#
# QuestionID: 1999-W38-1-9
# Answer: Right now, Canada has about 3,900 peacekeepers on 22 missions around the world.
#
#
# QuestionID: 1999-W38-1-10
# Answer:  The making sure that the people living protected from violence
#
#
# Total Accuracy:  52.71950271950272
# QuestionID: 1999-W39-1-1
# Answer:  "So you can see there's a real problem here."
#
#
# QuestionID: 1999-W39-1-2
# Answer:  They the n't its own language law
#
#
# QuestionID: 1999-W39-1-3
# Answer: There are a couple of thousand French speakers in the Northwest Territories, or about 2 people out every 100. | "Ultimately it's the federal government that is responsible for ensuring the equality of French and English in the territories, not only in the Northwest Territories, but also in Nunavut and in the Yukon."
#
#
# QuestionID: 1999-W39-1-4
# Answer:  `` The NWT French ''
#
#
# QuestionID: 1999-W39-1-5
# Answer:  federation found that 75 per cent it had
#
#
# QuestionID: 1999-W39-1-6
# Answer:  `` NWT French '' Andre Legare
#
#
# QuestionID: 1999-W39-1-7
# Answer:  should Northwest Territories next month
#
#
# QuestionID: 1999-W39-1-8
# Answer:  `` Ultimately Nunavut Yukon ''
#
#
# Total Accuracy:  27.592935759209343
# QuestionID: 1999-W39-3-1
# Answer: It took him four tries, but yesterday evening New Democratic Party leader Gary Doer finally achieved what he set out to do: win a provincial election and become the Premier of Manitoba.
#
#
# QuestionID: 1999-W39-3-2
# Answer:  After 11 long years as opposition Doer finally beat in yesterday 's election
#
#
# QuestionID: 1999-W39-3-4
# Answer:  He become known as `` hallway medicine ''
#
#
# QuestionID: 1999-W39-3-5
# Answer: The NDP could still add one more seat to the 31 it has won officially.
#
#
# QuestionID: 1999-W39-3-6
# Answer:  There -- -- Winnipeg Assiniboia Tory Linda McIntosh NDP Jim Rondeau 3
#
#
# QuestionID: 1999-W39-3-7
# Answer:  There -- -- Winnipeg Assiniboia Tory Linda McIntosh
#
#
# QuestionID: 1999-W39-3-8
# Answer:  took about 45 last night largest share party has won since Howard Pawley swept Conservative leader Sterling Lyon out power in 1981
#
#
# QuestionID: 1999-W39-3-9
# Answer:                     45                                                                                         1981
#
#
# Total Accuracy:  12.774930006587615
# QuestionID: 1999-W39-5-1
# Answer:  Teachers' union officials say that while they do not agree with the student demonstrations that are taking place during the school day, the boycott of extra-curricular activities would continue.
#
#
# QuestionID: 1999-W39-5-3
# Answer:  in contract discussions with
#
#
# QuestionID: 1999-W39-5-4
# Answer:  were 100 fines
#
#
# QuestionID: 1999-W39-5-5
# Answer:  Deputy Serge Meloche
#
#
# QuestionID: 1999-W39-5-6
# Answer:  During past few days have taken throughout
#
#
# QuestionID: 1999-W39-5-7
# Answer:  `` Windows of stores were broken car windows were also broken '' says Montreal spokesman Michel Fontaine who added that were also rocks and garbage
#
#
# QuestionID: 1999-W39-5-8
# Answer:  The 300 400
#
#
# Total Accuracy:  27.11893033075299
# QuestionID: 1999-W41-3-1
# Answer:  Reports 100 Thames Great Western
#
#
# QuestionID: 1999-W41-3-2
# Answer:  Reports said both were traveling about 100 km/h when Thames train tried to cross in front of Great Western train
#
#
# QuestionID: 1999-W41-3-3
# Answer:  A British Broadcasting Corporation
#
#
# QuestionID: 1999-W41-3-4
# Answer:  Tuesday's accident was Britain's worst rail crash since December 1988, when three trains collided outside London's Clapham Junction, killing 35 people.
#
#
# QuestionID: 1999-W41-3-5
# Answer:  Great Western and Thames are that two
#
#
# QuestionID: 1999-W41-3-6
# Answer: Great Western said as many as 500 people might have been on board its train, which originated in Cheltenham, northwest of London, and was minutes away from its destination of Paddington Station. | Reports said both trains were traveling about 100 km/h when the Thames train tried to cross in front of the Great Western train.
#
#
# QuestionID: 1999-W41-3-7
# Answer:  Reports 100 Thames
#
#
# QuestionID: 1999-W41-3-8
# Answer:  A British Broadcasting Corporation reporter says initial investigation suggests of passed red and yellow warning signals before hitting other train
#
#
# QuestionID: 1999-W41-3-9
# Answer:  Rail travel its
#
#
# Total Accuracy:  22.88359788359788
# QuestionID: 1999-W41-5-1
# Answer:  Governor General Allegiance Keeper Great Seal Canada
#
#
# QuestionID: 1999-W41-5-2
# Answer:  Oath Office Supreme Court Canada Justice Claire L'Heureux Dube
#
#
# QuestionID: 1999-W41-5-3
# Answer:  The Governor General formally takes once the oaths have been sworn and assumes the `` Excellency '' and the lifetime of `` Right Honourable ''
#
#
# QuestionID: 1999-W41-5-5
# Answer:  a fought back tears as she praised 92-year-old father and mother whom she said was there in spirit
#
#
# QuestionID: 1999-W41-5-6
# Answer:                                                   26
#
#
# QuestionID: 1999-W41-5-8
# Answer:  also thanked whom she said as `` bright not bright yellow ''
#
#
# QuestionID: 1999-W41-5-9
# Answer:  Queen England Canada
#
#
# QuestionID: 1999-W41-5-10
# Answer:  represents Queen England who is legal head Canada
#
#
# Total Accuracy:  22.250992063492063
# QuestionID: 1999-W43-5-1
# Answer:  a show that airs in some Canadian schools in trouble in Manitoba
#
#
# QuestionID: 1999-W43-5-2
# Answer: So far the ads have been about breakfast cereals and computer games.
#
#
# QuestionID: 1999-W43-5-3
# Answer:  makes by selling advertising space
#
#
# QuestionID: 1999-W43-5-4
# Answer: YNN presents a 12-minute daily feature shown during class time.
#
#
# QuestionID: 1999-W43-5-6
# Answer:  Education Minister Drew Caldwell
#
#
# QuestionID: 1999-W43-5-7
# Answer:  As of the end of June schools in Alberta Saskatchewan Manitoba Ontario Quebec and Newfoundland had agreed to show the news program run by Montreal-based Athena Educational Partners
#
#
# QuestionID: 1999-W43-5-8
# Answer:  British Columbia Nova Scotia and New Brunswick
#
#
# QuestionID: 1999-W43-5-9
# Answer:  agreed a six-month trial
#
#
# Total Accuracy:  54.79166666666666
# QuestionID: 1999-W45-5-1
# Answer:  Students Iqaluit Inuksuk High School 10,000
#
#
# QuestionID: 1999-W45-5-2
# Answer:  Students Iqaluit Susan Aglukark
#
#
# QuestionID: 1999-W45-5-3
# Answer: to experience different emotions," MacLeod said.
#
#
# QuestionID: 1999-W45-5-4
# Answer:  Students at Iqaluit 's are celebrating the revival of their with singer Susan Aglukark pizza and 10,000 cheque today
#
#
# QuestionID: 1999-W45-5-5
# Answer:  ''
#
#
# QuestionID: 1999-W45-5-6
# Answer:  arrived beginning of year
#
#
# QuestionID: 1999-W45-5-7
# Answer:  About 90 students or a quarter are
#
#
# QuestionID: 1999-W45-5-8
# Answer: Students can rent instruments from the South, but MacLeod says running a successful music program in the North often requires providing instruments for students. | A single instrument is often shared between two or three students.
#
#
# QuestionID: 1999-W45-5-9
# Answer:  For MacLeod
#
#
# Total Accuracy:  15.873015873015872
# QuestionID: 1999-W47-5-2
# Answer:  One Fujian Immigration Refugee Board
#
#
# QuestionID: 1999-W47-5-3
# Answer: because the board has found no evidence of persecution.
#
#
# QuestionID: 1999-W47-5-4
# Answer: The Chinese woman can't be identified because of a legal order, but it seems her claim to be accepted as a refugee to Canada may succeed where the claims of 32 people who arrived with her have failed.
#
#
# QuestionID: 1999-W47-5-5
# Answer:  woman ca n't be identified because of a legal order but it seems her claim be accepted as a Canada may succeed where claims of 32 who arrived with her have failed
#
#
# QuestionID: 1999-W47-5-6
# Answer:  says that seven years ago she got
#
#
# QuestionID: 1999-W47-5-7
# Answer: Couples in China are only allowed to have one child.
#
#
# QuestionID: 1999-W47-5-9
# Answer:  also says her family received a notice that 'll be sterilized so ca n't have any more babies
#
#
# QuestionID: 1999-W47-5-11
# Answer:  Federal Court Appeal Canada
#
#
# Total Accuracy:  14.384006892230577
# QuestionID: 1999-W49-5-1
# Answer:  the planet 's fiery red hue
#
#
# QuestionID: 1999-W49-5-3
# Answer:  has been hurtling through hundreds of millions of kilometres of space for past 11 months
#
#
# QuestionID: 1999-W49-5-4
# Answer:  For NASA Carl Sagan
#
#
# QuestionID: 1999-W49-5-5
# Answer:  There fears that hit a rock or lose contact with NASA back home
#
#
# QuestionID: 1999-W49-5-6
# Answer:
#
#
# QuestionID: 1999-W49-5-8
# Answer:  In Greece Rome
#
#
# QuestionID: 1999-W49-5-10
# Answer:  Any answers from probe would help focus future missions searching for past or present life which is dependent on water though fossils or living organisms
#
#
# Total Accuracy:  30.51282051282051
# QuestionID: 1999-W51-1-1
# Answer:  A Vancouver British Columbia judge has thrown out a copyright Canadian pop singer
#
#
# QuestionID: 1999-W51-1-2
# Answer:  A Vancouver British Columbia judge has a copyright lawsuit against Canadian pop singer Sarah
#
#
# QuestionID: 1999-W51-1-3
# Answer:  British Columbia Supreme Court Justice Bruce Cohen Darryl Neudorf
#
#
# QuestionID: 1999-W51-1-5
# Answer:  Neudorf 54-40 Vancouver Halifax Nova Scotia
#
#
# QuestionID: 1999-W51-1-6
# Answer: because she had never written songs before.
#
#
# QuestionID: 1999-W51-1-7
# Answer:  They said was properly compensated receiving about 4,000 in wages and royalties worth 16 cents on each `` Touch '' album sold
#
#
# QuestionID: 1999-W51-1-8
# Answer: He said he did not receive proper royalties for producing "Touch," which sold more than 625,000 copies. | They said Neudorf was properly compensated, receiving about $4,000 in wages and royalties worth 16 cents on each "Touch" album sold.
#
#
# QuestionID: 1999-W51-1-9
# Answer:  's lawyer Jennifer Conkie said the performer the of the popular Lilith Fair that toured North America is `` very very pleased and relieved ''
#
#
# QuestionID: 1999-W51-1-10
# Answer:  sang and played a keyboard before court staff reporters and teenaged fans to illustrate how songs are put together
#
#
# Total Accuracy:  18.702881264284773
# QuestionID: 2000-W02-3-1
# Answer:  63
#
#
# QuestionID: 2000-W02-3-2
# Answer:  They when tiny amounts of chlorine added to drinking water
#
#
# QuestionID: 2000-W02-3-3
# Answer:  trihalomethanes is faced mainly by small that ca n't afford expensive filtration systems
#
#
# QuestionID: 2000-W02-3-4
# Answer:  The charcoal will absorb the chemicals.
#
#
# QuestionID: 2000-W02-3-8
# Answer:  says that `` -- like they are doing now -- two years ago ''
#
#
# QuestionID: 2000-W02-3-9
# Answer:  You can leave open and will evaporate
#
#
# QuestionID: 2000-W02-3-10
# Answer:  The danger of trihalomethanes drinking is faced mainly by small towns that ca n't afford expensive filtration systems
#
#
# Total Accuracy:  44.69911041339613
# QuestionID: 2000-W02-5-1
# Answer:                     1998
#
#
# QuestionID: 2000-W02-5-2
# Answer:  CBC Online Eastern
#
#
# QuestionID: 2000-W02-5-3
# Answer:  open people 's eyes growing crisis in Canada
#
#
# QuestionID: 2000-W02-5-5
# Answer:  He says
#
#
# QuestionID: 2000-W02-5-8
# Answer:  Federal Agriculture Minister Lyle Vanclief
#
#
# Total Accuracy:  47.0
# QuestionID: 2000-W03-1-1
# Answer:  Green Nova Scotia Emergency Health Services -- -- OK. Cape Breton
#
#
# QuestionID: 2000-W03-1-2
# Answer: The five siblings sold more than two million records, won five Juno Awards, including group of the year in 1994, and took its Celtic music to the world.
#
#
# QuestionID: 2000-W03-1-3
# Answer:  Morris Green of Nova Scotia Emergency Health Services said one of the teenagers was being treated for -- when one 's body temperature drops abnormally low -- and the other two appeared to be OK. John Morris Rankin played fiddle and piano with the popular musical family from Cape Breton
#
#
# QuestionID: 2000-W03-1-4
# Answer:  a member former Celtic group Rankins was killed in accident
#
#
# QuestionID: 2000-W03-1-5
# Answer:  Farm Aid Toronto
#
#
# QuestionID: 2000-W03-1-6
# Answer:  Green of Nova Scotia Emergency Health Services said one of the teenagers was being treated for hypothermia -- when one 's body temperature drops abnormally low -- and the other two appeared to be OK. played fiddle and piano with the popular family from Cape Breton
#
#
# QuestionID: 2000-W03-1-7
# Answer:  Besides Michael 15 survived by his wife Sally and daughter 13
#
#
# QuestionID: 2000-W03-1-8
# Answer:  Family Russell De Carle
#
#
# QuestionID: 2000-W03-1-9
# Answer:  Family Nova Scotia
#
#
# QuestionID: 2000-W03-1-10
# Answer:  The group broke up last summer so its members could pursue independent careers and interests.
#
#
# Total Accuracy:  30.57389422172031
# QuestionID: 2000-W03-2-1
# Answer:  After more than a month of searching for a signal from NASA 's Mars mission controllers given up hope of finding it
#
#
# QuestionID: 2000-W03-2-2
# Answer:  `` We '' Richard Cook NASA Jet Propulsion Laboratory
#
#
# QuestionID: 2000-W03-2-3
# Answer:  Polar Lander
#
#
# QuestionID: 2000-W03-2-4
# Answer:  NASA sent a spacecraft called to take high-resolution images of landing site to search for signs of lander
#
#
# QuestionID: 2000-W03-2-5
# Answer:  on a to to study its atmosphere and search for water something that could help scientists determine whether life ever existed on
#
#
# QuestionID: 2000-W03-2-7
# Answer: The failed mission to the Red Planet cost the American government more than $200 million dollars.
#
#
# QuestionID: 2000-W03-2-8
# Answer: The failed mission to the Red Planet cost the American government more than $200 million dollars.
#
#
# QuestionID: 2000-W03-2-9
# Answer:  Another lander and orbiter are scheduled to launch but at least the is now in doubt
#
#
# QuestionID: 2000-W03-2-11
# Answer: The Mars Polar Lander was on a mission to Mars to study its atmosphere and search for water, something that could help scientists determine whether life ever existed on Mars.
#
#
# Total Accuracy:  15.221661054994387
# QuestionID: 2000-W03-3-2
# Answer:  Federal National League Canada
#
#
# QuestionID: 2000-W03-3-3
# Answer: to give the teams money will last four years.
#
#
# QuestionID: 2000-W03-3-4
# Answer: The average NHL player makes 1.3 million dollars a season.
#
#
# QuestionID: 2000-W03-3-5
# Answer:  He says that it not fair that millionaire hockey players like Turner Stevenson and are getting help while hundreds of Olympic athletes have to scramble every month just to pay their bills
#
#
# QuestionID: 2000-W03-3-6
# Answer:  The subsidies could add up to millions of dollars
#
#
# QuestionID: 2000-W03-3-7
# Answer:  `` I 've been this for 13 or 14 years running on the national team and we 've been forced to live on from 450 a month to 810 a month '' said from Austin where he training for the Sydney Olympics
#
#
# QuestionID: 2000-W03-3-8
# Answer:  Rosann Wowchuk Ottawa
#
#
# QuestionID: 2000-W03-3-9
# Answer:  The Federal government plan give the will last four years
#
#
# QuestionID: 2000-W03-3-10
# Answer:  Federal to give teams money last four years
#
#
# Total Accuracy:  20.40895061728395
# QuestionID: 2000-W05-4-1
# Answer: to two - India in the south, where a majority of the population believes in the Hindu religion, and Pakistan in the north, where the majority of the population believes in the Muslim religion.
#
#
# QuestionID: 2000-W05-4-2
# Answer:  had obtained permission to shoot film from Indian federal Information and Broadcasting Ministry as well as government of state where film is being shot
#
#
# QuestionID: 2000-W05-4-3
# Answer:  had obtained Indian federal Information and Broadcasting Ministry as well as government of state where is being shot
#
#
# QuestionID: 2000-W05-4-4
# Answer:  But after the attack by strongly religious people who refuse anything that disagrees with their faith Indian government authorities withdrew their permission to shoot the film in Varanasi
#
#
# QuestionID: 2000-W05-4-5
# Answer:  Indian-born
#
#
# QuestionID: 2000-W05-4-6
# Answer: Mehta says the attack has cost the production about a million dollars in damage and delays in the shooting schedule.
#
#
# QuestionID: 2000-W05-4-7
# Answer:  Last year pulled from theatres in India after violent protests by Hindu nationalists
#
#
# QuestionID: 2000-W05-4-8
# Answer:                                                                  1947
#
#
# QuestionID: 2000-W05-4-9
# Answer:  Mahatma Gandhi Britain
#
#
# Total Accuracy:  22.12168913149305
# QuestionID: 2000-W06-5-1
# Answer:  Cochrane Alberta Canada
#
#
# QuestionID: 2000-W06-5-2
# Answer:  plans team six other climbers this May in Yukon Territory
#
#
# QuestionID: 2000-W06-5-3
# Answer:  Watson May Mount Yukon Territory
#
#
# QuestionID: 2000-W06-5-4
# Answer:  is big fan of the outdoors who describes `` scrambler '' when it comes to climbing
#
#
# QuestionID: 2000-W06-5-5
# Answer:  The 49-year-old who lost vision from pellet gun at the age 12 says lack technical ability
#
#
# QuestionID: 2000-W06-5-6
# Answer:  Ten years ago scaled Alaska 's Mount North America 's highest mountain
#
#
# QuestionID: 2000-W06-5-7
# Answer: because the wrong messages are rolling through our heads.
#
#
# QuestionID: 2000-W06-5-8
# Answer:                                                                                     5 945
#
#
# QuestionID: 2000-W06-5-9
# Answer:  The 49-year-old who lost from a pellet gun at the age of 12 says lack of technical climbing ability is more of a challenge than blindness
#
#
# QuestionID: 2000-W06-5-10
# Answer:  The 49-year-old who lost his vision from a pellet gun at the age of 12 says his lack of technical climbing ability is more of a challenge than his blindness
#
#
# Total Accuracy:  25.52029914529915
# QuestionID: 2000-W07-5-1
# Answer:  's won 27 percent of the vote 's last election and earlier this month they joined the conservative People 's a coalition government
#
#
# QuestionID: 2000-W07-5-2
# Answer:  Nazi Germany 1930 Second World War
#
#
# QuestionID: 2000-W07-5-3
# Answer:  a Nazi sympathizer
#
#
# QuestionID: 2000-W07-5-5
# Answer:  Jewish United States
#
#
# QuestionID: 2000-W07-5-6
# Answer: because even their clothes reflect their beliefs.
#
#
# QuestionID: 2000-W07-5-7
# Answer: because even their clothes reflect their beliefs.
#
#
# QuestionID: 2000-W07-5-8
# Answer: Heshy Weinberger, a spokesman for the Tash Hasidic community in a Montreal suburb, says it is not true that Heider was invited to attend the wedding.
#
#
# QuestionID: 2000-W07-5-9
# Answer:  Raoul Wallenberg European Jews
#
#
# Total Accuracy:  41.964285714285715
# Total Accuracy:  30.26034851232866
